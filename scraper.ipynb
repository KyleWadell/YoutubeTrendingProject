# %%
import scraper as scr

# %%
scr.setup("/Users/Bwang/Desktop/Trending-YouTube-Scraper-master/api_key.txt", "/Users/Bwang/Desktop/Trending-YouTube-Scraper-master/country_codes.txt")
# Out:
# ('AIzaSyBtE0bhjwmMo8U7VV10HGrI-xHlTIQV5MY',
#  ['US', 'GB', 'IN', 'DE', 'CA', 'FR', 'KR', 'RU', 'JP', 'BR', 'MX'])

# %%
scr.api_request("&","US")
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/6g-POWHqdfV3YxSH5gAYYo76B58"',
#  'nextPageToken': 'CDIQAA',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#video',
#    'etag': '"j6xRRd8dTPVVptg711_CSPADRfg/OxhPnpHWtZilMs8XLBh6hEj9wgw"',
#    'id': 'zlJDTxahav0',
#    'snippet': {'publishedAt': '2019-10-23T04:00:11.000Z',
#     'channelId': 'UCjK8ORC71kwyj1DWFwril_A',
#     'title': 'Selena Gomez - Lose You To Love Me (Official Video)',
# ...
