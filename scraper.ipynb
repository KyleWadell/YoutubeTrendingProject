# %%
import scraper as scr
import pandas as pd
import time
import datetime

# %%
scr.setup("api_key.txt", "country_codes.txt")
# Out:
# ('AIzaSyBtE0bhjwmMo8U7VV10HGrI-xHlTIQV5MY',
#  ['US', 'GB', 'IN', 'DE', 'CA', 'FR', 'KR', 'RU', 'JP', 'BR', 'MX'])

# %%
def pull_data(T,dt):
    snippet_features = ["title",
                        "publishedAt",
                        "channelId",
                        "channelTitle",
                        "categoryId"]

    # Any characters to exclude, generally these are things that become problematic in CSV files
    unsafe_characters = ['\n', '"']

    # Used to identify columns, currently hardcoded order
    header = ["video_id"] + snippet_features + ["trending_date", "tags", "view_count", "likes", "dislikes",
                                                "comment_count", "thumbnail_link", "comments_disabled",
                                                "ratings_disabled", "description","observed_time"]
    data = pd.DataFrame(columns = header)
    for t in list(range(0,T,dt)):
        raw = scr.api_request("&","US")
        for row in scr.get_videos(raw['items']):
            proc_row = []
            for i in row.split('"'):
                if i != '' and i != ' ' and i != ',':
                    proc_row.append(i)
            proc_row.append(datetime.datetime.now())
            data.loc[len(data)] = proc_row
        time.sleep(60*dt)
    return data

# %%
data = pull_data(2,1)

# %%
data
# Out:
#        video_id                                              title  \
# 0   HPJKxAhLw5I  Planting 20,000,000 Trees, My Biggest Project ...
# 1   U7nJBFjKqAY             Using Drones to Plant 20,000,000 Trees
# 2   JqFzflBD5e0         The Evolution Of Pennywise / IT (Animated)
# 3   6CNPg2IQoC0                                              Selah
# 4   rKDFCWt6rVs    Repaint! The GOATMAN Halloween Custom OOAK Doll
# 5   fXM5WF2SCio  The Scariest Nails On the Internet (Simply Rev...
# 6   OWyCcObW_0c                    $17 Vs. $2200 Halloween Costume
# 7   6aUBgJxi5Ik  HYDRO DiP💧HYDRO FLASK !! 💦 (Satisfying) ft. Lo...
# 8   eKxDjG9barU  Burnley v. Chelsea | PREMIER LEAGUE HIGHLIGHTS...
# 9   4RpZ1mwrceg   Stuntmen React To Bad & Great Hollywood Stunts 7
# 10  nhVUAyyUqGQ                  Building my Cat an Outdoor House!
# 11  W1bfcLnrsDc  Can You Find Him in This Video? • Hidden in Pl...
# 12  e6At--20uk8            K. Michelle - THE RAIN (Official Video)
# ...
